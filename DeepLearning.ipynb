# %% [markdown]
# Deep Learning LAB Digital Assessment – 3
# Name :Raghav Agarwalm
# Registration Number : 21BD19249
# Course : Deep Learning LAB
# Slot : L59+L60

# %% [markdown]
# 1. Build an ANN using Keras for the following input and output with 1 hidden layer of 10 neuron and
# 1 output layer neuron for 20 epochs with batchsize 10, adam and binary cross entropy loss
# x_train_data = np.random.random((1000, 10))
# y_train_data = np.random.randint(2, size=(1000, 1))

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import matplotlib.pyplot as plt

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam

# Generate random training data
x_train_data = np.random.random((1000, 10))
y_train_data = np.random.randint(2, size=(1000, 1))

# Generate random test data
x_test_data = np.random.random((100, 10))
y_test_data = np.random.randint(2, size=(100, 1))

# Create the ANN model
model = Sequential()

# Add a hidden layer with 10 neurons and ReLU activation
model.add(Dense(10, activation='relu', input_shape=(10,)))

# Add an output layer with 1 neuron and sigmoid activation for binary classification
model.add(Dense(1, activation='sigmoid'))

# Compile the model with Adam optimizer, binary cross entropy loss, and accuracy as a metric
model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy'])

# Fit/Train the model for 20 epochs with a batch size of 10
history = model.fit(x_train_data, y_train_data, epochs=20, batch_size=10, validation_split=0.2)

# Evaluate the model on the test data
test_loss, test_acc = model.evaluate(x_test_data, y_test_data)

# Print test loss and accuracy
print(f'Test Loss: {test_loss}')
print(f'Test Accuracy: {test_acc}')

# Plotting the training history: Loss and Accuracy
def plot_history(history):
    # Plot training & validation accuracy values
    plt.figure(figsize=(12, 5))
    
    # Accuracy plot
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='Train Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.title('Model Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend(loc='upper left')
    
    # Loss plot
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Model Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend(loc='upper left')

    # Show plots
    plt.tight_layout()
    plt.show()

# Call the function to plot loss and accuracy
plot_history(history)
# Out:
# Epoch 1/20
# C:\Users\ASUS\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4992 - loss: 0.6937 - val_accuracy: 0.4450 - val_loss: 0.6978
# Epoch 2/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4853 - loss: 0.7000 - val_accuracy: 0.4450 - val_loss: 0.6971
# Epoch 3/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4939 - loss: 0.6925 - val_accuracy: 0.4300 - val_loss: 0.6983
# Epoch 4/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5129 - loss: 0.6907 - val_accuracy: 0.4400 - val_loss: 0.6981
# Epoch 5/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5142 - loss: 0.6931 - val_accuracy: 0.4450 - val_loss: 0.6986
# Epoch 6/20
# ...

# %% [markdown]
# 2. Use the following code to formulate a binary classification dataset for iris flower classification.Further build an ANN sequential model with Keras ,train ,test and plot the accuarcy with different validation split.
# from sklearn.datasets import load_iris
# import pandas as pd
# Load the Iris dataset
# iris = load_iris()
# Create ,Compile,Fit/Train,Evaluate/Test, Plot Loss and Accuracy

# %%
# Import necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer
from sklearn.metrics import confusion_matrix
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import CategoricalCrossentropy

# Step 1: Load and prepare the Iris dataset
iris = load_iris()
X = iris['data']  # Features
y = iris['target']  # Labels (target classes)

# Step 2: One-hot encode the labels (for 3 classes)
lb = LabelBinarizer()
y_one_hot = lb.fit_transform(y)  # Convert labels to one-hot encoded

# Step 3: Split the data into train and test sets (80% train, 20% test)
X_train, X_test, y_train, y_test = train_test_split(X, y_one_hot, test_size=0.2, random_state=42)

# Step 4: Build the ANN model for multiclass classification
model = Sequential()
model.add(Dense(10, input_dim=4, activation='relu'))  # 1 hidden layer with 10 neurons
model.add(Dense(3, activation='softmax'))  # Output layer for 3 classes with softmax

# Step 5: Compile the model
model.compile(optimizer=Adam(), loss=CategoricalCrossentropy(), metrics=['accuracy'])

# Step 6: Train the model with different validation splits (using 20% of training data for validation)
history = model.fit(X_train, y_train, epochs=20, batch_size=10, validation_split=0.2, verbose=0)

# Step 7: Evaluate the model on the test data
test_loss, test_acc = model.evaluate(X_test, y_test, verbose=0)

# Step 8: Plot the training and validation loss and accuracy
plt.figure(figsize=(12, 5))

# Plot Loss
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss per Epoch')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Plot Accuracy
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy per Epoch')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# Step 9: Print the test loss and accuracy
print(f"Test Loss: {test_loss}")
print(f"Test Accuracy: {test_acc}")

# Step 10: Predict class labels for the test set (Convert from one-hot encoding)
y_pred = model.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true_classes = np.argmax(y_test, axis=1)

# Step 11: Confusion Matrix
cm = confusion_matrix(y_true_classes, y_pred_classes)

# Plot Confusion Matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=iris['target_names'], yticklabels=iris['target_names'])
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
# Out:
# C:\Users\ASUS\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Test Loss: 0.6278592348098755
# Test Accuracy: 0.8999999761581421
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step

# %% [markdown]
# 3. Suppose you are building a linear mean-square model based on this data to predict the customers’ credit scores.¶
# Let us denote the three input variables (the first three columns of the table) as x1, x2 and x3, while the output variable as y. Consider the following datag![image.png](attachment:1c62e856-0cfd-4615-9414-3a2bd8d82b4c.png)
#
# Create a Sequential model in keras and add a dense layer of 2 neuron with relu activation.
# add an output layer of 1 neuron with sigmoid activation function.
# Compile the model, Train the model and then evaluate the model by plotting the accuracy and loss
# Using the model, compute the credit score for the following cus
# ![image.png](attachment:4c2acd46-bc24-45ad-b814-6c6aaad588e9.png)![image.png](attachment:aa1f2272-81c0-40b1-a037-5386eea5f7e8.png)mage.png

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
from sklearn.preprocessing import StandardScaler

# Step 1: Define the input data (Monthly Income, Monthly Expenses, Home Owner) and output data (Credit Score)
X_train = np.array([[2, 1, 0],
                    [1, 2, 0],
                    [6, 2, 1],
                    [3, 1, 1],
                    [3, 2, 0]])

y_train = np.array([3, 1, 5, 4, 2])  # Credit Scores

# Step 2: Normalize the input data
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)

# Step 3: Build the Sequential model
model = Sequential()
model.add(Dense(2, input_dim=3, activation='relu'))  # Dense layer with 2 neurons and ReLU activation
model.add(Dense(1, activation='sigmoid'))  # Output layer with 1 neuron and sigmoid activation

# Step 4: Compile the model
model.compile(optimizer=Adam(), loss='mean_squared_error', metrics=['mae', 'accuracy'])

# Step 5: Train the model with validation split
history = model.fit(X_train_scaled, y_train, epochs=50, batch_size=1, validation_split=0.2, verbose=0)

# Step 6: Plot the training loss, mean absolute error (MAE), and accuracy
plt.figure(figsize=(14, 6))

# Plot Loss
plt.subplot(1, 3, 1)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss per Epoch')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Plot Mean Absolute Error (MAE)
plt.subplot(1, 3, 2)
plt.plot(history.history['mae'], label='Train MAE')
plt.plot(history.history['val_mae'], label='Validation MAE')
plt.title('Mean Absolute Error per Epoch')
plt.xlabel('Epochs')
plt.ylabel('MAE')
plt.legend()

# Plot Accuracy
plt.subplot(1, 3, 3)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy per Epoch')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# Step 7: Predict the credit score for a new customer
new_customer = np.array([[5, 3, 1]])  # Monthly Income = 5, Monthly Expenses = 3, Home Owner = 1
new_customer_scaled = scaler.transform(new_customer)  # Normalize the input data
predicted_score = model.predict(new_customer_scaled)
predicted_score = predicted_score[0][0] * 5  # Scale back to the original credit score range
print(f"Predicted Credit Score for the new customer: {predicted_score:.2f}")
# Out:
# C:\Users\ASUS\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step
# Predicted Credit Score for the new customer: 2.72

# %% [markdown]
# 4. Build A basic CNN with three convolutional layers followed by max-pooling layers, and two dense layers at the end.¶
# The model should be compiled with the Adam optimizer and trained on the MNIST dataset for 5 epochs.
# Finally, evaluate the model on the test set and prints the test accuracy with plots.
# Layer (typ                  e)	Output Shape
# conv2d (Conv                  2D)	(None, 26, 26, 32)
# max_pooling2d (MaxPoolin  g2D)	(None, 13, 13, 32)
# conv2d_1 (Co              nv2D)	(None, 11, 11, 64)
# max_pooling2d_1 (MaxPool  ing2D)	(None, 5, 5, 64)
# conv2d_2 (              Conv2D)	(None, 3, 3, 64)
# flatten (              Flatten)	(None, 576)
# dens                  e (Dense)	(None, 64)
# dense                  _1 (Dense)	(None, 10)

# %%
# Import necessary libraries
import tensorflow as tf
from tensorflow.keras import layers, models
import matplotlib.pyplot as plt

# Step 1: Load and preprocess the MNIST dataset
mnist = tf.keras.datasets.mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Normalize the input data to be between 0 and 1
x_train = x_train.reshape(-1, 28, 28, 1).astype('float32') / 255.0
x_test = x_test.reshape(-1, 28, 28, 1).astype('float32') / 255.0

# One-hot encode the labels
y_train = tf.keras.utils.to_categorical(y_train, 10)
y_test = tf.keras.utils.to_categorical(y_test, 10)

# Step 2: Build the CNN model
model = models.Sequential()

# First convolutional layer followed by max pooling
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)))
model.add(layers.MaxPooling2D((2, 2)))

# Second convolutional layer followed by max pooling
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))

# Third convolutional layer
model.add(layers.Conv2D(64, (3, 3), activation='relu'))

# Flatten the output to feed into Dense layers
model.add(layers.Flatten())

# First dense layer
model.add(layers.Dense(64, activation='relu'))

# Output layer with 10 units (for 10 classes) and softmax activation
model.add(layers.Dense(10, activation='softmax'))

# Step 3: Compile the model
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Step 4: Train the model for 5 epochs
history = model.fit(x_train, y_train, epochs=5, batch_size=64, validation_data=(x_test, y_test))

# Step 5: Evaluate the model on the test set
test_loss, test_accuracy = model.evaluate(x_test, y_test)
print(f'Test accuracy: {test_accuracy:.4f}')

# Step 6: Plot the training history (accuracy and loss)

# Plot accuracy
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy per Epoch')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Plot loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss per Epoch')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# C:\Users\ASUS\anaconda3\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 37s 32ms/step - accuracy: 0.8634 - loss: 0.4460 - val_accuracy: 0.9805 - val_loss: 0.0604
# Epoch 2/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 26s 27ms/step - accuracy: 0.9835 - loss: 0.0538 - val_accuracy: 0.9869 - val_loss: 0.0394
# Epoch 3/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 25s 27ms/step - accuracy: 0.9880 - loss: 0.0382 - val_accuracy: 0.9900 - val_loss: 0.0308
# Epoch 4/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 26s 27ms/step - accuracy: 0.9920 - loss: 0.0259 - val_accuracy: 0.9907 - val_loss: 0.0294
# Epoch 5/5
# ...

# %%
# Import necessary libraries
from sklearn.metrics import confusion_matrix
import seaborn as sns
import numpy as np

# Step 7: Predict the test set results
y_pred = model.predict(x_test)
y_pred_classes = np.argmax(y_pred, axis=1)  # Convert predictions to class labels
y_true = np.argmax(y_test, axis=1)  # Convert one-hot encoded test labels to class labels

# Step 8: Compute the confusion matrix
cm = confusion_matrix(y_true, y_pred_classes)

# Step 9: Plot the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=range(10), yticklabels=range(10))
plt.title('Confusion Matrix')
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step

# %% [markdown]
# 5. Consider a colour images to be restricted to the size of 224x224 squares and apply the image to the pre trained VGG16 network further determine the name of the object of the image
# ![download.png](attachment:692b090d-47c6-4bbb-8da2-cd987a5f26fe.png)

# %%
import tensorflow as tf
from tensorflow.keras.applications.vgg16 import VGG16, preprocess_input, decode_predictions
from tensorflow.keras.preprocessing import image
import numpy as np
import os

# Download a sample image dataset from the internet (can be replaced with other URLs)
img_url = 'https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz'
img_path = tf.keras.utils.get_file('flower_photos.tgz', origin=img_url, extract=True)

# Adjust the path to the sample image after extraction (you'll need to explore the directory to find exact path)
# Here's how you can find the sample image file after extraction
sample_image_dir = os.path.join(os.path.dirname(img_path), 'flower_photos')  # Directory where images are extracted

# Just for simplicity, let's load the first image we find in the directory (you can replace this with a specific image path)
sample_image = None
for root, dirs, files in os.walk(sample_image_dir):
    for file in files:
        if file.endswith(('jpg', 'jpeg', 'png')):  # Find image files
            sample_image = os.path.join(root, file)
            break

# Check if an image was found
if sample_image is None:
    raise Exception("No images found in the extracted dataset.")

# Load the image and preprocess it for VGG16
img = image.load_img(sample_image, target_size=(224, 224))
img_array = image.img_to_array(img)
img_array = np.expand_dims(img_array, axis=0)
img_array = preprocess_input(img_array)

# Load the VGG16 model pre-trained on ImageNet
model = VGG16(weights='imagenet')

# Perform inference
predictions = model.predict(img_array)

# Decode the predictions into human-readable labels
decoded_predictions = decode_predictions(predictions, top=3)[0]

# Print and save the top predictions
output_text = "Top predictions for the image:\n"
for i, (imagenet_id, label, score) in enumerate(decoded_predictions):
    output_text += f"{i+1}: {label} ({score*100:.2f}%)\n"
    
print(output_text)

# Save the results to a text file in the Kaggle working directory
output_file = '/kaggle/working/vgg16_predictions.txt'
with open(output_file, 'w') as f:
    f.write(output_text)

print(f"Predictions saved to {output_file}")
# Out:
# ...
# 228813984/228813984 ━━━━━━━━━━━━━━━━━━━━ 375s 2us/step
# ...
# 553467096/553467096 ━━━━━━━━━━━━━━━━━━━━ 845s 2us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# ...
# 35363/35363 ━━━━━━━━━━━━━━━━━━━━ 0s 2us/step
# Top predictions for the image:
# 1: picket_fence (80.45%)
# 2: cock (5.08%)
# 3: daisy (4.47%)
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[13], line 51
#      49 # Save the results to a text file in the Kaggle working directory
#      50 output_file = '/kaggle/working/vgg16_predictions.txt'
# ---> 51 with open(output_file, 'w') as f:
#      52     f.write(output_text)
#      54 print(f"Predictions saved to {output_file}")
#
# File ~\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
# ...
